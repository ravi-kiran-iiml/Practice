# %% [markdown]
# <a href="https://colab.research.google.com/github/ravi-kiran-iiml/Practice/blob/main/BM-Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook 03

# %%
param1 = ['complementing_partner','fintech_partner'] 
param2 = ['closed_market', 'open_market', 'whitelabel_market']
param3 = ['financial_products','non_financial_products']
param4 = ['partner_sell_only','partner_cocreate_and_sell']
param5 = ['bank_sell_only','bank_cocreate_and_sell']
param6 = ['bank_frontfacing', 'bank_embedded_in_partner']
param7 = ['large_corporate_partner','premium_brand_partner','other_companies_partner']

param_list = [param1, param2, param3,param4, param5, param6, param7]

# %%
num_models = 2*3*2*2*2*2*3
print(num_models)
# Out:
# 288

# %%
def list_expand(*args):
  global param_list
  factors_list = []
  for param in param_list:
    for factor in param:
      factors_list.append(factor)
  #print(factors_list)
  return factors_list

print(list_expand(param_list))
# Out:
# ['complementing_partner', 'fintech_partner', 'closed_market', 'open_market', 'whitelabel_market', 'financial_products', 'non_financial_products', 'partner_sell_only', 'partner_cocreate_and_sell', 'bank_sell_only', 'bank_cocreate_and_sell', 'bank_frontfacing', 'bank_embedded_in_partner', 'large_corporate_partner', 'premium_brand_partner', 'other_companies_partner']

# %%
from itertools import combinations

def factor_combination(*args):
  global param_list
  factors_list = list_expand(param_list)
  dimensions = len(param_list)
  combinations_array = []

  comb = combinations(factors_list, dimensions)

  for i in list(comb):
    #print(i)
    combinations_array.append(i)
  
  #print(len(combinations_array))
  return combinations_array #, len(combinations_array)

factor_combination()
# Out:
# [('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'financial_products',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_sell_only',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_sell_only',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_cocreate_and_sell',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'partner_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'whitelabel_market',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'partner_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'financial_products',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'non_financial_products',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_sell_only',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_sell_only',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_frontfacing',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_frontfacing',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_frontfacing',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_frontfacing',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_frontfacing',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_frontfacing',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_embedded_in_partner',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_embedded_in_partner',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'bank_embedded_in_partner',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'open_market',
#   'large_corporate_partner',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'partner_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'non_financial_products',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'financial_products',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'closed_market',
#   'whitelabel_market',
#   'non_financial_products',
#   'bank_cocreate_and_sell',
# ...
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'non_financial_products',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'bank_sell_only'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'partner_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_cocreate_and_sell'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_cocreate_and_sell',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_sell_only',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'bank_embedded_in_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_cocreate_and_sell',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'bank_embedded_in_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_frontfacing',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'large_corporate_partner',
#   'premium_brand_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'large_corporate_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'bank_embedded_in_partner',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ('complementing_partner',
#   'fintech_partner',
#   'open_market',
#   'financial_products',
#   'large_corporate_partner',
#   'premium_brand_partner',
#   'other_companies_partner'),
#  ...]

# %%
"""
def factor_combination(*args):
  global param_list
  factors_list = list_expand(param_list)
  dimensions = len(param_list)
  n_models = 1
  for param in param_list:
    n_models = n_models * len(param) 
  #print("Factors: ", factors_list)
  #print("Dimensions: ",dimensions, "," ,"No of Models: ",n_models)
  combinations = []
  for i in range(n_models):
    one_model = []
    for j in range(dimensions):
      one_model.append(factors_list[j])
    combinations.append(one_model)
  #print(combinations)
  return combinations

print(factor_combination())
"""
# Out:
# '\ndef factor_combination(*args):\n  global param_list\n  factors_list = list_expand(param_list)\n  dimensions = len(param_list)\n  n_models = 1\n  for param in param_list:\n    n_models = n_models * len(param) \n  #print("Factors: ", factors_list)\n  #print("Dimensions: ",dimensions, "," ,"No of Models: ",n_models)\n  combinations = []\n  for i in range(n_models):\n    one_model = []\n    for j in range(dimensions):\n      one_model.append(factors_list[j])\n    combinations.append(one_model)\n  #print(combinations)\n  return combinations\n\nprint(factor_combination())\n'

# %%
def eliminate_models(*args):
  global param_list
  combinations = factor_combination()
  
  new_combination = []

  for combination in combinations:
    combination = list(combination)
    x = 0
    combination.append(x)
    x_ind = combination.index(x)
    
    for param in param_list:
      #print(param)
      count_param = 0
      for factor in param:
        #print(param, factor)
        if factor in combination:
          count_param += 1
      #print(param, count_param)
      if count_param > 1:
        x += 1
    
    #print(x)
    combination[x_ind] = x
    #print(combination.index(x))
    new_combination.append(combination)

  new_combination = [item for item in new_combination if item[7] == 0]
  new_combination = [item[:len(item)-1] for item in new_combination]

  return new_combination #, len(new_combination)

eliminate_models()
# Out:
# [['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['complementing_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'closed_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'open_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_sell_only',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_sell_only',
#   'bank_embedded_in_partner',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_frontfacing',
#   'other_companies_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'large_corporate_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'premium_brand_partner'],
#  ['fintech_partner',
#   'whitelabel_market',
#   'non_financial_products',
#   'partner_cocreate_and_sell',
#   'bank_cocreate_and_sell',
#   'bank_embedded_in_partner',
#   'other_companies_partner']]

# %%
import pandas as pd

def output_models(*args):
  global param_list
  models = eliminate_models()
  model_df = pd.DataFrame(models)
  #print(model_df)
  #model_df.to_csv('Models.csv')
  return model_df

output_models()
# Out:
#                          0                  1                       2  \
# 0    complementing_partner      closed_market      financial_products
# 1    complementing_partner      closed_market      financial_products
# 2    complementing_partner      closed_market      financial_products
# 3    complementing_partner      closed_market      financial_products
# 4    complementing_partner      closed_market      financial_products
# ..                     ...                ...                     ...
# 283        fintech_partner  whitelabel_market  non_financial_products
# 284        fintech_partner  whitelabel_market  non_financial_products
# 285        fintech_partner  whitelabel_market  non_financial_products
# 286        fintech_partner  whitelabel_market  non_financial_products
# 287        fintech_partner  whitelabel_market  non_financial_products
#
#                              3                       4  \
# 0            partner_sell_only          bank_sell_only
# 1            partner_sell_only          bank_sell_only
# 2            partner_sell_only          bank_sell_only
# 3            partner_sell_only          bank_sell_only
# 4            partner_sell_only          bank_sell_only
# ..                         ...                     ...
# 283  partner_cocreate_and_sell  bank_cocreate_and_sell
# 284  partner_cocreate_and_sell  bank_cocreate_and_sell
# 285  partner_cocreate_and_sell  bank_cocreate_and_sell
# 286  partner_cocreate_and_sell  bank_cocreate_and_sell
# 287  partner_cocreate_and_sell  bank_cocreate_and_sell
#
#                             5                        6
# 0            bank_frontfacing  large_corporate_partner
# 1            bank_frontfacing    premium_brand_partner
# 2            bank_frontfacing  other_companies_partner
# 3    bank_embedded_in_partner  large_corporate_partner
# 4    bank_embedded_in_partner    premium_brand_partner
# ..                        ...                      ...
# 283          bank_frontfacing    premium_brand_partner
# 284          bank_frontfacing  other_companies_partner
# 285  bank_embedded_in_partner  large_corporate_partner
# 286  bank_embedded_in_partner    premium_brand_partner
# 287  bank_embedded_in_partner  other_companies_partner
#
# [288 rows x 7 columns]

# %%
def upload_score_matrix(*args):
  score_matrix = pd.read_csv('Parameter Scores.csv')
  #print(score_matrix)
  return score_matrix

upload_score_matrix()
# Out:
#                            Factor  New Markets / Customers  \
# 0           complementing_partner                      3.0
# 1                 fintech_partner                      2.0
# 2                     open_market                      3.0
# 3                   closed_market                      2.0
# 4               whitelabel_market                      1.5
# 5              financial_products                      1.8
# 6          non_financial_products                      2.0
# 7               partner_sell_only                      2.0
# 8       partner_cocreate_and_sell                      3.0
# 9        bank_embedded_in_partner                      3.0
# 10  product_bundling_bank_partner                      2.5
# 11               bank_frontfacing                      1.0
# 12                 bank_sell_only                      2.0
# 13         bank_cocreate_and_sell                      3.0
# 14          premium_brand_partner                      2.0
# 15        large_corporate_partner                      2.0
# 16        other_companies_partner                      2.0
#
#     New Products / Services  Higher Customer Engagement  Innovation  \
# 0                       2.0                         1.0         1.5
# 1                       3.0                         2.0         1.5
# 2                       3.0                         1.0         1.5
# 3                       1.5                         1.5         2.0
# 4                       1.5                         2.0         1.0
# 5                       2.0                         2.0         2.0
# 6                       1.0                         2.0         0.7
# 7                       1.0                         1.8         1.0
# 8                       3.0                         2.3         2.5
# 9                       0.5                         2.3         1.0
# 10                      3.0                         2.0         3.0
# 11                      1.0                         2.0         1.0
# 12                      0.7                         1.5         1.0
# 13                      3.0                         2.3         2.5
# 14                      2.0                         3.0         2.0
# 15                      1.5                         3.0         1.0
# 16                      2.0                         1.5         2.3
#
#     Ops Efficiency  Increased Brand Value  Better CX  More/Relevant Data  \
# 0              1.0                    3.0        1.5                 3.0
# 1              1.0                    2.0        2.5                 2.0
# 2              0.5                    2.5        1.5                 1.8
# 3              1.0                    2.2        1.8                 1.8
# 4              1.0                    3.0        1.5                 1.0
# 5              2.0                    3.0        2.0                 3.0
# 6              0.7                    1.5        1.0                 0.5
# 7              2.0                    2.3        2.0                 2.0
# 8              1.5                    2.5        2.5                 2.0
# 9              2.0                    2.5        2.5                 2.5
# 10             1.5                    3.0        3.0                 2.0
# 11             1.0                    3.0        2.0                 3.0
# 12             1.5                    2.0        1.5                 0.5
# 13             1.5                    2.5        2.5                 2.0
# 14             2.5                    3.0        3.0                 2.5
# 15             1.0                    3.0        2.0                 3.0
# 16             1.0                    2.0        1.6                 2.3
#
#     Higher Impact
# 0             2.0
# 1             1.0
# 2             2.0
# 3             1.0
# 4             1.0
# 5             2.0
# 6             0.8
# 7             1.7
# 8             1.5
# 9             2.0
# 10            2.0
# 11            2.0
# 12            1.0
# 13            1.5
# 14            1.5
# 15            2.0
# 16            2.0

# %%
def factor_synergy_dict(*args):
  df = upload_score_matrix()
  df_factor = df.T
  scores_dict = {}
  index_list = list(df_factor.index.values)
  index_list = index_list[1:]
  #print(index_list)
  df_factor.columns = df_factor.iloc[0]
  df_factor = df_factor.drop(df_factor.index[0])
  factors_list = list(df_factor.columns)
  #print(factors_list)

  factor_synergy_list = []

  for factor in factors_list:
    z = zip(index_list, df_factor[factor])
    #factor_synergy_list.append([factor,[]])
    for item in list(z):
      factor_synergy_list.append([factor, item])
        
  return df_factor #factor_synergy_list,  

factor_synergy_dict()
# Out:
# Factor                     complementing_partner fintech_partner open_market  \
# New Markets / Customers                      3.0             2.0         3.0
# New Products / Services                      2.0             3.0         3.0
# Higher Customer Engagement                   1.0             2.0         1.0
# Innovation                                   1.5             1.5         1.5
# Ops Efficiency                               1.0             1.0         0.5
# Increased Brand Value                        3.0             2.0         2.5
# Better CX                                    1.5             2.5         1.5
# More/Relevant Data                           3.0             2.0         1.8
# Higher Impact                                2.0             1.0         2.0
#
# Factor                     closed_market whitelabel_market financial_products  \
# New Markets / Customers              2.0               1.5                1.8
# New Products / Services              1.5               1.5                2.0
# Higher Customer Engagement           1.5               2.0                2.0
# Innovation                           2.0               1.0                2.0
# Ops Efficiency                       1.0               1.0                2.0
# Increased Brand Value                2.2               3.0                3.0
# Better CX                            1.8               1.5                2.0
# More/Relevant Data                   1.8               1.0                3.0
# Higher Impact                        1.0               1.0                2.0
#
# Factor                     non_financial_products partner_sell_only  \
# New Markets / Customers                       2.0               2.0
# New Products / Services                       1.0               1.0
# Higher Customer Engagement                    2.0               1.8
# Innovation                                    0.7               1.0
# Ops Efficiency                                0.7               2.0
# Increased Brand Value                         1.5               2.3
# Better CX                                     1.0               2.0
# More/Relevant Data                            0.5               2.0
# Higher Impact                                 0.8               1.7
#
# Factor                     partner_cocreate_and_sell bank_embedded_in_partner  \
# New Markets / Customers                          3.0                      3.0
# New Products / Services                          3.0                      0.5
# Higher Customer Engagement                       2.3                      2.3
# Innovation                                       2.5                      1.0
# Ops Efficiency                                   1.5                      2.0
# Increased Brand Value                            2.5                      2.5
# Better CX                                        2.5                      2.5
# More/Relevant Data                               2.0                      2.5
# Higher Impact                                    1.5                      2.0
#
# Factor                     product_bundling_bank_partner bank_frontfacing  \
# New Markets / Customers                              2.5              1.0
# New Products / Services                              3.0              1.0
# Higher Customer Engagement                           2.0              2.0
# Innovation                                           3.0              1.0
# Ops Efficiency                                       1.5              1.0
# Increased Brand Value                                3.0              3.0
# Better CX                                            3.0              2.0
# More/Relevant Data                                   2.0              3.0
# Higher Impact                                        2.0              2.0
#
# Factor                     bank_sell_only bank_cocreate_and_sell  \
# New Markets / Customers               2.0                    3.0
# New Products / Services               0.7                    3.0
# Higher Customer Engagement            1.5                    2.3
# Innovation                            1.0                    2.5
# Ops Efficiency                        1.5                    1.5
# Increased Brand Value                 2.0                    2.5
# Better CX                             1.5                    2.5
# More/Relevant Data                    0.5                    2.0
# Higher Impact                         1.0                    1.5
#
# Factor                     premium_brand_partner large_corporate_partner  \
# New Markets / Customers                      2.0                     2.0
# New Products / Services                      2.0                     1.5
# Higher Customer Engagement                   3.0                     3.0
# Innovation                                   2.0                     1.0
# Ops Efficiency                               2.5                     1.0
# Increased Brand Value                        3.0                     3.0
# Better CX                                    3.0                     2.0
# More/Relevant Data                           2.5                     3.0
# Higher Impact                                1.5                     2.0
#
# Factor                     other_companies_partner
# New Markets / Customers                        2.0
# New Products / Services                        2.0
# Higher Customer Engagement                     1.5
# Innovation                                     2.3
# Ops Efficiency                                 1.0
# Increased Brand Value                          2.0
# Better CX                                      1.6
# More/Relevant Data                             2.3
# Higher Impact                                  2.0

# %%
def calc_model_score(*args):
  global param_list
  df_factor = factor_synergy_dict()
  models_dataframe = output_models()
  f = upload_score_matrix()
  #print(models_dataframe)

  synergies_list = list(f.columns)[1:]
  #print(synergies_list)

  import numpy as np

  d = pd.DataFrame(0, index=np.arange(len(models_dataframe.index)), columns=synergies_list)
  #print(d)
  models_dataframe = pd.concat([models_dataframe, d], axis=1)
  #print(models_dataframe)
  #print(models_dataframe.columns)
  #print(df_factor)


  # Score Addition to DataFrame
  for i in range(len(models_dataframe)):
    for synergy in synergies_list:
      models_dataframe.at[i, synergy] = 0
      synergy_score = 0
      for j in range(len(param_list)):
        synergy_score += df_factor.at[synergy, models_dataframe.at[i,j]]
      models_dataframe.at[i,synergy] = synergy_score
      pass
  #scored_model = pd.DataFrame()
  return models_dataframe #scored_model

calc_model_score()
# Out:
#                          0                  1                       2  \
# 0    complementing_partner      closed_market      financial_products
# 1    complementing_partner      closed_market      financial_products
# 2    complementing_partner      closed_market      financial_products
# 3    complementing_partner      closed_market      financial_products
# 4    complementing_partner      closed_market      financial_products
# ..                     ...                ...                     ...
# 283        fintech_partner  whitelabel_market  non_financial_products
# 284        fintech_partner  whitelabel_market  non_financial_products
# 285        fintech_partner  whitelabel_market  non_financial_products
# 286        fintech_partner  whitelabel_market  non_financial_products
# 287        fintech_partner  whitelabel_market  non_financial_products
#
#                              3                       4  \
# 0            partner_sell_only          bank_sell_only
# 1            partner_sell_only          bank_sell_only
# 2            partner_sell_only          bank_sell_only
# 3            partner_sell_only          bank_sell_only
# 4            partner_sell_only          bank_sell_only
# ..                         ...                     ...
# 283  partner_cocreate_and_sell  bank_cocreate_and_sell
# 284  partner_cocreate_and_sell  bank_cocreate_and_sell
# 285  partner_cocreate_and_sell  bank_cocreate_and_sell
# 286  partner_cocreate_and_sell  bank_cocreate_and_sell
# 287  partner_cocreate_and_sell  bank_cocreate_and_sell
#
#                             5                        6  \
# 0            bank_frontfacing  large_corporate_partner
# 1            bank_frontfacing    premium_brand_partner
# 2            bank_frontfacing  other_companies_partner
# 3    bank_embedded_in_partner  large_corporate_partner
# 4    bank_embedded_in_partner    premium_brand_partner
# ..                        ...                      ...
# 283          bank_frontfacing    premium_brand_partner
# 284          bank_frontfacing  other_companies_partner
# 285  bank_embedded_in_partner  large_corporate_partner
# 286  bank_embedded_in_partner    premium_brand_partner
# 287  bank_embedded_in_partner  other_companies_partner
#
#      New Markets / Customers  New Products / Services  \
# 0                         13                        9
# 1                         13                       10
# 2                         13                       10
# 3                         15                        9
# 4                         15                        9
# ..                       ...                      ...
# 283                       14                       14
# 284                       14                       14
# 285                       16                       13
# 286                       16                       14
# 287                       16                       14
#
#      Higher Customer Engagement  Innovation  Ops Efficiency  \
# 0                            12           9               9
# 1                            12          10              11
# 2                            11          10               9
# 3                            13           9              10
# 4                            13          10              12
# ..                          ...         ...             ...
# 283                          15          11               9
# 284                          14          11               7
# 285                          15          10               8
# 286                          15          11              10
# 287                          14          11               8
#
#      Increased Brand Value  Better CX  More/Relevant Data  Higher Impact
# 0                       18         12                  16             11
# 1                       18         13                  15             11
# 2                       17         12                  15             11
# 3                       18         13                  15             11
# 4                       18         14                  15             11
# ..                     ...        ...                 ...            ...
# 283                     17         15                  13              9
# 284                     16         13                  12              9
# 285                     17         14                  13              9
# 286                     17         15                  12              9
# 287                     16         14                  12              9
#
# [288 rows x 16 columns]

# %%
"""

def final_df(*args):
  global param_list
  df = calc_model_score()
  synergy_start_index = df.columns.get_loc('New Markets / Customers')
  synergy_close_index = df.columns.get_loc('Higher Impact')
  
  #df['Total'] = [0 for i in range(len(df))]

  df = df.assign('Total'=df[["A", "B"]].sum(axis=1))

  #for i in range(len(df)):
   # for j in range(synergy_start_index:synergy_close_index+1):
    #  df.at[i,'Total'] = 
\
"""
# Out:
# '\n\ndef final_df(*args):\n  global param_list\n  df = calc_model_score()\n  synergy_start_index = df.columns.get_loc(\'New Markets / Customers\')\n  synergy_close_index = df.columns.get_loc(\'Higher Impact\')\n  \n  #df[\'Total\'] = [0 for i in range(len(df))]\n\n  df = df.assign(\'Total\'=df[["A", "B"]].sum(axis=1))\n\n  #for i in range(len(df)):\n   # for j in range(synergy_start_index:synergy_close_index+1):\n    #  df.at[i,\'Total\'] = \n'

# %%
def Consolidated_file(*args):
  final_model = calc_model_score()
  #final_file = final_model.to_csv('Final Model.csv')
  return
